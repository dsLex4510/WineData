# %% [markdown]
# # Wine Variety Prediction Using Logistic Regression

# %% [markdown]
# Members:
# - Mamaril, Ramil
# - Cabarrubias, Jhon Roe
# - Villegas, Lex

# %% [markdown]
# ![kisspng-leonardo-dicaprio-jay-gatsby-the-great-gatsby-film-leonardo-dicaprio-5ab68382309d81.1446887215219106581991.jpg](attachment:kisspng-leonardo-dicaprio-jay-gatsby-the-great-gatsby-film-leonardo-dicaprio-5ab68382309d81.1446887215219106581991.jpg)

# %% [markdown]
# This is a data set of wine from kaggle. The purpose of this data set is to mimic the expertise of some sommelier (wine expert) on the taste of different wine, their origin or country, the qualities it contain based on the description.
#
# source: https://www.kaggle.com/zynicide/wine-reviews

# %% [markdown]
# ### Importation of Libraries needed

# %%
#Import Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Data Selection

# %%
file = open('C:/Users/Lex/Documents/College/3rd Year/1st Semester/Machine Learning/Lab Files/Wine Project/winemag-data_first150k.csv' ,encoding = "ISO-8859-1")
wine_data = pd.read_csv(file)
wine_data
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La BÃ©gude, named af...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# 0                           Martha's Vineyard      96  235.0
# 1       Carodorum SelecciÃ³n Especial Reserva      96  110.0
# 2               Special Selected Late Harvest      96   90.0
# 3                                     Reserve      96   65.0
# 4                                 La BrÃ»lade      95   66.0
# ...                                       ...     ...    ...
# 150925                                    NaN      91   20.0
# 150926                        CuvÃ©e Prestige      91   27.0
# 150927                          Terre di Dora      91   20.0
# 150928                       Grand Brut RosÃ©      90   52.0
# 150929                                    NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                    winery
# 0       Cabernet Sauvignon                     Heitz
# 1            Tinta de Toro  Bodega Carmen RodrÃ­guez
# 2          Sauvignon Blanc                  Macauley
# 3               Pinot Noir                     Ponzi
# 4       Provence red blend     Domaine de la BÃ©gude
# ...                    ...                       ...
# 150925         White Blend     Feudi di San Gregorio
# 150926     Champagne Blend                 H.Germain
# 150927         White Blend                 Terredora
# 150928     Champagne Blend                    Gosset
# 150929        Pinot Grigio             Alois Lageder
#
# [150930 rows x 10 columns]

# %%
wine_data.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
wine_data.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# Since the target prediction here is the Variety and Origin. We only extract the columns like country(origin), description (taste), points (wine grade), price of the wine, and its variety (Wine name). Other attributes other than the Variety and Origin is solely for descriptive purposes or more detailed view of the predicted value.

# %%
#Selected Data into Array
Extracted_data = wine_data[['country', 'description', 'points', 'price', 'variety']]
Extracted_data.sample(5)
# Out:
#           country                                        description  points  \
# 18507          US  A tough, gritty wine, with lots of stinging ac...      86
# 129968         US  From warm, dry vineyards in the eastern Vaca m...      90
# 127128  Australia  Pretty good Merlot, with varietally correct sc...      87
# 45832          US  A nice, crisp white wine, juicy and fruity in ...      86
# 144096         US  This is three quarters Cabernet Sauvignon, the...      92
#
#         price                   variety
# 18507    50.0                Pinot Noir
# 129968   24.0                 Zinfandel
# 127128   20.0                    Merlot
# 45832    15.0                Pinot Gris
# 144096   40.0  Bordeaux-style Red Blend

# %%
Extracted_data.shape
# Out:
# (150930, 5)

# %% [markdown]
# ### Data Pre-Processing

# %%
Extracted_data.isnull().sum()
# Out:
# country            5
# description        0
# points             0
# price          13695
# variety            0
# dtype: int64

# %%
#Eliminate Rows with Null/Missing Values
Extracted_data.dropna(inplace = True)
# Out:
# <ipython-input-8-8ed1b177be18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Extracted_data.dropna(inplace = True)

# %%
print(Extracted_data.shape[0])
# Out:
# 137230

# %%
Extracted_data.isnull().sum()
# Out:
# country        0
# description    0
# points         0
# price          0
# variety        0
# dtype: int64

# %%
Extracted_data.variety.unique()
# Out:
# array(['Cabernet Sauvignon', 'Tinta de Toro', 'Sauvignon Blanc',
#        'Pinot Noir', 'Provence red blend', 'Friulano', 'Tannat',
#        'Chardonnay', 'Tempranillo', 'Malbec', 'RosÃ©',
#        'Tempranillo Blend', 'Syrah', 'Mavrud', 'Sparkling Blend',
#        'Sangiovese', 'RhÃ´ne-style White Blend', 'Red Blend',
#        'MencÃ\xada', 'Palomino', 'Petite Sirah', 'Riesling',
#        'Cabernet Sauvignon-Syrah', 'Portuguese Red', 'Pinot Gris',
#        'Nebbiolo', 'Meritage', 'Baga', 'Glera', 'Malbec-Merlot',
#        'Merlot-Malbec', 'Ugni Blanc-Colombard', 'Viognier',
#        'Cabernet Sauvignon-Cabernet Franc', 'Moscato', 'Pinot Grigio',
#        'Cabernet Franc', 'White Blend', 'Gamay', 'Zinfandel', 'Greco',
#        'Barbera', 'Grenache', 'RhÃ´ne-style Red Blend', 'AlbariÃ±o',
#        'Malvasia Bianca', 'Assyrtiko', 'Malagouzia', 'CarmenÃ¨re',
#        'Bordeaux-style Red Blend', 'Touriga Nacional', 'Agiorgitiko',
#        'Picpoul', 'Godello', 'GewÃ¼rztraminer', 'Merlot',
#        'Syrah-Grenache', 'G-S-M', 'MourvÃ¨dre',
#        'Bordeaux-style White Blend', 'Petit Verdot', 'Muscat',
#        'Cabernet Sauvignon-Merlot', 'Pinot Bianco', 'Alvarinho',
#        'Portuguese White', 'Garganega', 'Sauvignon', 'Tannat-Cabernet',
#        'Alicante Bouschet', 'AragonÃªs', 'Silvaner', 'Ugni Blanc',
#        'GrÃ¼ner Veltliner', 'Frappato', 'Lemberger', 'Sylvaner',
#        'Chasselas', 'Alsace white blend', 'FrÃ¼burgunder', 'Kekfrankos',
#        'Vermentino', 'Sherry', 'Aglianico', 'TorrontÃ©s', 'Primitivo',
#        'Semillon-Sauvignon Blanc', 'Portuguese RosÃ©', 'Grenache-Syrah',
#        'Furmint', 'Carignane', 'Pinot Blanc', 'St. Laurent',
#        'Blauburgunder', 'BlaufrÃ¤nkisch', 'Scheurebe', 'Ribolla Gialla',
#        'Charbono', 'Malbec-Cabernet Sauvignon', 'Pinot Noir-Gamay',
#        'Pinot Nero', 'Gros Manseng', 'Nerello Mascalese', 'Shiraz',
#        'Negroamaro', 'Champagne Blend', 'Romorantin',
#        'Syrah-Cabernet Sauvignon', 'Tannat-Merlot', 'Duras', 'Garnacha',
#        'Tinta Francisca', 'Portuguese Sparkling', 'Chenin Blanc',
#        'Turbiana', 'Petite Verdot', 'Posip', 'FumÃ© Blanc', 'Monastrell',
#        'Roussanne', 'MÃ¼ller-Thurgau', 'Pinot Auxerrois', 'Port',
#        'Cabernet Blend', 'Cabernet Franc-Cabernet Sauvignon', 'CastelÃ£o',
#        'Encruzado', 'Touriga Nacional-Cabernet Sauvignon',
#        'Colombard-Sauvignon Blanc', 'Moscatel', 'Marsanne', 'Siria',
#        'Garnacha Blanca', 'Merlot-Cabernet Sauvignon', 'Arinto', 'Melon',
#        'Carricante', 'Fiano', 'Schwartzriesling', 'Sangiovese-Syrah',
#        'Tannat-Cabernet Franc', 'Cabernet Franc-Merlot',
#        'Sauvignon Blanc-Semillon', 'Macabeo', 'Alfrocheiro', 'AligotÃ©',
#        'Verdejo', 'Grenache Blanc', 'SpÃ¤tburgunder', 'Ciliegiolo',
#        'Cabernet Sauvignon-CarmenÃ¨re', 'Auxerrois', 'Sirica', 'Zweigelt',
#        'Negrette', 'Pugnitello', 'Rosado', 'Grillo', 'Rosato',
#        'Malvazija', 'Kalecik Karasi', 'Muskat Ottonel', 'Malbec-Bonarda',
#        'Tempranillo-Cabernet Sauvignon', 'Rivaner', 'Trepat', 'Baco Noir',
#        'Trebbiano', 'Chardonnay-Viognier', 'Syrah-MourvÃ¨dre', 'Graciano',
#        'Perricone', 'Falanghina', 'Vranec', 'Carignan', 'Cabernet-Shiraz',
#        'Verdelho', 'Pedro XimÃ©nez', 'Marsanne-Roussanne', 'Malbec Blend',
#        'Weissburgunder', 'Morava', 'Ruen', 'Hondarrabi Zuri',
#        'Catarratto', 'Chardonnay-Sauvignon Blanc', 'Vidal', 'Rieslaner',
#        'Dornfelder', 'Tinto Fino', 'Chenin Blanc-Chardonnay',
#        'Gelber Muskateller', 'Roter Veltliner', 'Aragonez', 'Vitovska',
#        'Pinot Noir-Syrah', 'Gamay Noir', 'Grauburgunder', 'Cannonau',
#        "Nero d'Avola", 'Mauzac', 'Gros and Petit Manseng', 'SÃ©millon',
#        'Lambrusco di Sorbara', 'Teran', 'Dolcetto', 'Cinsault',
#        'Assyrtico', 'Teroldego', 'Tamjanika', 'BoÄ\x9fazkere', 'Kadarka',
#        'Narince', 'Malbec-Petit Verdot', 'Veltliner', 'Traminer',
#        'Lambrusco', 'Arneis', 'Cabernet Sauvignon-Shiraz',
#        'Tocai Friulano', 'Fer Servadou', 'Muskateller',
#        'Nerello Cappuccio', 'Moscatel Roxo', 'Elbling', 'Saperavi',
#        'AntÃ£o Vaz', 'Pinot Meunier', 'Petite Syrah', 'Malvasia',
#        'Malbec-Tannat', 'Kallmet', 'Syrah-Merlot', 'Montepulciano',
#        'Kerner', 'PriÃ© Blanc', 'Å½ilavka', 'Chardonnay-Semillon',
#        'CarmenÃ¨re-Cabernet Sauvignon', 'Loureiro',
#        'Merlot-Cabernet Franc', 'Orangetraube',
#        'Cabernet Sauvignon-Sangiovese', 'Okuzgozu', 'Viura',
#        'Garnacha-Syrah', 'Zibibbo', 'Feteasca', 'Xarel-lo', 'Prokupac',
#        'CÃ³dega do Larinho', 'Inzolia', 'Cabernet-Syrah',
#        'Lambrusco Grasparossa', 'Malagousia', 'Austrian Red Blend',
#        'Cabernet Franc-Malbec', 'Feteasca Neagra', 'Yapincak',
#        'Tempranillo-Shiraz', 'Cabernet Sauvignon Grenache', 'Tinta Roriz',
#        'Merlot-Syrah', 'Tinta Fina', 'Colombard-Ugni Blanc', 'Colombard',
#        'Roditis', 'Grenache-Carignan', 'Emir', 'Orange Muscat',
#        'Karalahna', 'Trincadeira', 'FernÃ£o Pires', 'Refosco',
#        'Pied de Perdrix', 'Vignoles', 'Carignan-Grenache',
#        "Muscat d'Alexandrie", 'Bobal', 'Symphony', 'Norton', 'Rkatsiteli',
#        'Roussanne-Viognier', 'Pinela', 'Blatina', 'Shiraz-Viognier',
#        'Bonarda', 'Sauvignon Blanc-Chardonnay', 'Chambourcin',
#        'Traminette', 'Grenache Blend', 'Jaen', 'Mondeuse',
#        'FeteascÇ\x8e RegalÇ\x8e', 'Teroldego Rotaliano',
#        'Sangiovese-Cabernet Sauvignon', 'ListÃ¡n Negro',
#        'Syrah-Petite Sirah', 'Viognier-Chardonnay', 'Kuntra', 'JacquÃ¨re',
#        'Portuguiser', 'Verdejo-Viura', 'Tinto del Pais', 'Moscato Giallo',
#        'Cabernet Sauvignon-Malbec', 'Mission', 'Neuburger', 'Bastardo',
#        'Bical', 'CarineÃ±a', 'Garnacha-Tempranillo', 'Pecorino',
#        'Garnacha Blend', 'Cococciola', 'Passerina', 'Gaglioppo',
#        'Garnacha Tintorera', 'Prieto Picudo', 'Tempranillo Blanco',
#        "Cesanese d'Affile", 'Muscat Canelli', 'Cabernet', 'Malvasia Nera',
#        'Premsal', 'Mansois', 'Petit Manseng', 'Welschriesling',
#        'Shiraz-Tempranillo', 'Verdicchio', 'Sagrantino', 'Rolle',
#        'Trousseau Gris', 'Counoise', 'Mantonico', 'Grecanico',
#        'CariÃ±ena-Garnacha', 'Tokaji', 'Austrian white blend',
#        'Shiraz-Grenache', 'Claret', 'Syrah-Tempranillo', 'Uva di Troia',
#        'Aleatico', 'Viognier-Marsanne', 'Pinot Grigio-Sauvignon Blanc',
#        'Pallagrello Nero', 'Chardonnay-AlbariÃ±o', 'Savagnin', 'Pinotage',
#        'Braucol', 'Moschofilero', 'Nero di Troia', 'Carignano',
#        'Susumaniello', 'Baga-Touriga Nacional', 'Vidal Blanc',
#        'Vernaccia', 'Corvina, Rondinella, Molinara', 'Mavrotragano',
#        'Garnacha-Monastrell', 'Cabernet Merlot', 'Monastrell-Syrah',
#        'Malbec-Tempranillo', 'Syrah-Viognier', 'Verdeca', 'Insolia',
#        'Merlot-Argaman', 'Chenin Blanc-Viognier', 'Sangiovese Grosso',
#        'Garnacha-Cabernet', 'Maturana', 'Malvar', 'Airen', 'Monica',
#        'GewÃ¼rztraminer-Riesling', 'Lagrein', 'Steen',
#        'Chenin Blanc-Sauvignon Blanc', 'Shiraz-Cabernet Sauvignon',
#        'Picolit', 'Prosecco', 'White Riesling', 'Petroulianos',
#        'Mavrodaphne', 'Savatiano', 'Tempranillo-Garnacha', 'Vidadillo',
#        'Syrah-Cabernet', 'Grenache-Shiraz', 'Prugnolo Gentile',
#        'Rotgipfler', 'Cabernet Sauvignon-Tempranillo', 'Edelzwicker',
#        'Cortese', 'Chardonnay Weissburgunder', 'Torbato', 'Verduzzo',
#        'Debit', 'Bovale', 'Tempranillo-Merlot', 'Xinisteri', 'Piedirosso',
#        'Merlot-Cabernet', 'Verdejo-Sauvignon Blanc', 'Black Muscat',
#        'Koshu', 'KirÃ¡lyleÃ¡nyka', 'Favorita', 'Xinomavro',
#        'Cserszegi FÅ±szeres', 'HÃ¡rslevelÃ¼', 'Pallagrello', 'Mavroudi',
#        'Muscat Blanc', 'Schiava', 'Meoru', 'Trebbiano di Lugana',
#        'Coda di Volpe', 'Raboso', 'Shiraz-Pinotage', 'Greco Bianco',
#        'Tai', 'Tokay', 'Muscadel', 'Cabernet Franc-CarmenÃ¨re',
#        'Tintilia ', 'Segalin', 'Lacrima', 'Cerceal', 'Cayuga',
#        'Sauvignon Gris', 'Albana', 'Corvina', 'Macabeo-Moscatel',
#        'Macabeo-Chardonnay', 'Moscadello', 'Viognier-Roussanne',
#        'Plavac Mali', 'Cabernet Sauvignon-Merlot-Shiraz',
#        'Sauvignon Blanc-Chenin Blanc', 'Shiraz-MourvÃ¨dre', 'AlbarÃ\xadn',
#        'Black Monukka', 'Morio Muskat', 'Nielluciu',
#        'Touriga Nacional Blend', 'Alicante',
#        'Cabernet Sauvignon and Tinta Roriz', 'Viura-Chardonnay',
#        'Karasakiz', 'Casavecchia', 'Malvasia-Viura', 'Nosiola',
#        'Incrocio Manzoni', 'Viura-Verdejo', 'Erbaluce', 'ForcallÃ\xa0',
#        'Pansa Blanca', 'Catalanesca', 'Zierfandler', 'Muscadelle',
#        'Malbec-Syrah', 'Pignoletto', 'Cabernet Pfeffer',
#        'Syrah-Cabernet Franc', 'ValdiguiÃ©', 'Mazuelo', 'Brachetto',
#        'Jacquez', 'Moscofilero', 'Chardonnay-Sauvignon',
#        'Madeleine Angevine', 'RuchÃ©', 'Merlot-Petite Verdot',
#        'Roussanne-Marsanne', 'Moscatel de AlejandrÃ\xada',
#        'Muscat Blanc Ã\xa0 Petit Grain', 'SÃ¤mling', 'Mtsvane',
#        'Zlahtina', 'DoÃ±a Blanca', 'CarmenÃ¨re-Syrah',
#        'Roussanne-Grenache Blanc', 'Kinali Yapincak', 'Robola',
#        'Pinot Blanc-Chardonnay', 'Saperavi-Merlot', 'Malvasia Istriana',
#        'Torontel', 'Picapoll', 'Zierfandler-Rotgipfler', 'Malvasia Fina',
#        'Chinuri', 'Muscatel', 'SousÃ£o', 'Silvaner-Traminer',
#        'Syrah-Carignan', 'Bukettraube', 'Argaman', 'Provence white blend',
#        'Touriga Franca', 'Morillon', 'Carignan-Syrah', 'Aidani',
#        'Viognier-Grenache Blanc', 'Albarossa', 'Sauvignon Blanc-Verdejo',
#        "Loin de l'Oeil", 'Grenache-MourvÃ¨dre', 'Tannat-Syrah',
#        'Seyval Blanc', 'Tocai Rosso', 'Alvarinho-Chardonnay',
#        'Pinot-Chardonnay', 'Moscatel GraÃºdo', 'Pigato', 'Siegerrebe',
#        'Bombino Bianco', 'Trebbiano-Malvasia', 'Magliocco',
#        'Verduzzo Friulano ', 'Vespaiolo', 'Marzemino',
#        'Tempranillo-Malbec', 'Crespiello', 'Cabernet Franc-Tempranillo',
#        'Roviello', 'Caprettone', 'Garnacha-Graciano', 'Mataro',
#        'Moscato di Noto', 'Sauvignonasse', 'Madeira Blend', 'St. George',
#        'Nasco', 'Rebula', 'Chardonnay-Pinot Blanc', 'Pallagrello Bianco',
#        'Vilana', 'Pelaverga Piccolo', 'Syrah-Grenache-Viognier',
#        'Nuragus', 'AlvarelhÃ£o', 'Durif', 'Angevine',
#        'Semillon-Chardonnay', 'Pinot Blanc-Pinot Noir',
#        'Johannisberg Riesling', 'Manzoni', 'MarÃ©chal Foch',
#        'Blauer Portugieser', 'Shiraz-Malbec', 'VinhÃ£o',
#        'Cabernet Moravia', 'PaÃ\xads', 'Altesse', 'Avesso', 'Mandilaria',
#        'Freisa', 'Merlot-Shiraz', 'Dafni', 'Xynisteri', 'Roscetto',
#        'Sideritis', 'Pinotage-Merlot', 'Grolleau', 'Gragnano', 'Ansonica',
#        'Sangiovese Cabernet', 'Tinta Barroca', 'Syrah-Bonarda',
#        'Marsanne-Viognier', 'Azal', 'Durello', 'Syrah-Malbec',
#        'Malbec-Cabernet Franc', 'Franconia', 'Rufete', 'Parraleta',
#        'St. Vincent', 'Groppello', 'Athiri', 'Muscat of Alexandria',
#        'Malvoisie', 'Grignolino', 'Colorino', 'Merlot-Grenache',
#        'Grechetto', 'Chardonel', 'Macabeo-GewÃ¼rztraminer',
#        'Grenache Gris', 'Muscat Hamburg', 'Sarba', 'Roter Traminer',
#        'Irsai Oliver', 'Chardonnay-Pinot Gris', 'Vermentino Nero',
#        'Pardina', 'Apple', 'Clairette', 'Sauvignon MusquÃ©',
#        'Shiraz-Merlot', 'Viognier-ValdiguiÃ©', 'Chardonelle', 'Sercial',
#        'Malmsey', 'Bual', 'Tinta Negra Mole', 'Pinot Grigio-Chardonnay',
#        'White Port', 'Muscadet', 'Viura-Sauvignon Blanc', 'Tocai',
#        'Huxelrebe', 'Tokay Pinot Gris', 'Chardonnay-Pinot Grigio',
#        'Moristel', 'Carnelian'], dtype=object)

# %%
Extracted_data.variety.nunique()
# Out:
# 619

# %%
Extracted_data.drop(Extracted_data[Extracted_data.variety.str.contains('Ã')
                                  |Extracted_data.variety.str.contains('Ä')
                                  |Extracted_data.variety.str.contains('Â') 
                                  |Extracted_data.variety.str.contains('Ç')].index, inplace = True)
# Out:
# C:\Users\Lex\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Extracted_data.variety.nunique()
# Out:
# 560

# %%
Extracted_data.shape
# Out:
# (128252, 5)

# %%
Extracted_data.to_csv('Extracted_data.csv', index = True)

# %%
Extracted_data.variety.value_counts().head(15)
# Out:
# Chardonnay                  13775
# Pinot Noir                  13625
# Cabernet Sauvignon          12671
# Red Blend                    9377
# Sauvignon Blanc              6054
# Syrah                        5667
# Riesling                     5212
# Merlot                       4987
# Bordeaux-style Red Blend     4545
# Zinfandel                    3794
# Malbec                       3085
# Sangiovese                   2879
# White Blend                  2554
# Tempranillo                  2525
# Shiraz                       1945
# Name: variety, dtype: int64

# %% [markdown]
# For faster training of data and model fitting. We only selected the top 15 wine variety.

# %%
top = ['Chardonnay', 'Pinot Noir', 'Cabernet Sauvignon', 'Red Blend', 'Sauvignon Blanc', 
       'Syrah', 'Riesling', 'Merlot', 'Bordeaux-style Red Blend', 'Zinfandel',
       'Malbec', 'Sangiovese', 'White Blend', 'Tempranillo', 'Shiraz']
final_data = Extracted_data.loc[Extracted_data['variety'].isin(top)]

# %%
final_data.shape
# Out:
# (92695, 5)

# %%
final_data
# Out:
#        country                                        description  points  \
# 0           US  This tremendous 100% varietal wine hails from ...      96
# 2           US  Mac Watson honors the memory of a wine once ma...      96
# 3           US  This spent 20 months in 30% new French oak, an...      96
# 8           US  This re-named vineyard was formerly bottled as...      95
# 9           US  The producer sources from two blocks of the vi...      95
# ...        ...                                                ...     ...
# 150911  France  This needs a good bit of breathing time, then ...      87
# 150912  France  The nose is dominated by the attractive scents...      87
# 150915      US  Decades ago, Beringerâs then-winemaker Myron...      93
# 150925   Italy  Many people feel Fiano represents southern Ita...      91
# 150927   Italy  This classic example comes from a cru vineyard...      91
#
#         price             variety
# 0       235.0  Cabernet Sauvignon
# 2        90.0     Sauvignon Blanc
# 3        65.0          Pinot Noir
# 8        65.0          Pinot Noir
# 9        60.0          Pinot Noir
# ...       ...                 ...
# 150911   37.0          Pinot Noir
# 150912   65.0          Pinot Noir
# 150915   30.0         White Blend
# 150925   20.0         White Blend
# 150927   20.0         White Blend
#
# [92695 rows x 5 columns]

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# In order to make the description into something machine readable data. You need to perform text mining on the description of the wine. In that case, we use a python library called "SpaCy" for text mining.

# %%
#SpaCy for Text Mining
import os
import spacy as sc
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

#punctuation removal
punctuations = string.punctuation

#Stop words filtering
nlp = sc.load('en_core_web_sm')
stop_words = sc.lang.en.stop_words.STOP_WORDS
parser = English()

#Main Tokenizer Function
def spacy_tokenizer(sentence):
    # Token object
    mytokens = parser(sentence)

    # Lemmatization and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens
# Out:
# C:\Users\Lex\anaconda3\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Custom transformer using spaCy
from sklearn.base import TransformerMixin

class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
CV = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1), stop_words = 'english')

#Pipeline
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', CV)])
    
CV_Bag = CV.fit_transform(final_data['description'])

# %%
#Assign Numerical Values to the categories.
from sklearn.preprocessing import LabelEncoder
Labels = LabelEncoder()
#final_data['country'], uniques = pd.factorize(final_data['country'])
#final_data['variety'], uniques = pd.factorize(final_data['variety'])
final_data['country_num'] = Labels.fit_transform(final_data['country'])
final_data['variety_num'] = Labels.fit_transform(final_data['variety'])
# Out:
# <ipython-input-24-930fbfaa7301>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['country_num'] = Labels.fit_transform(final_data['country'])
# <ipython-input-24-930fbfaa7301>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['variety_num'] = Labels.fit_transform(final_data['variety'])

# %%
final_data.to_csv("Final_Wine_Data.csv", index = True)

# %% [markdown]
# ### Data Mining

# %%
#Assign the Variables
x = final_data.description #Independent Variable
y = final_data.variety #Dependent Variable
#np.asarray(Extracted_data[['country', 'variety']])
print(x.shape)
print(y.shape)
# Out:
# (92695,)
# (92695,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 1, test_size = 0.30)

# %%
CV.fit(x_train)
# Out:
# C:\Users\Lex\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# CountVectorizer(stop_words='english',
#                 tokenizer=<function spacy_tokenizer at 0x00000219BA4CFCA0>)

# %%
x_train_dtm = CV.transform(x_train)
x_train_dtm = CV.fit_transform(x_train)
x_train_dtm
# Out:
# <64886x25257 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1518072 stored elements in Compressed Sparse Row format>

# %%
x_test_dtm = CV.transform(x_test)
x_test_dtm
# Out:
# <27809x25257 sparse matrix of type '<class 'numpy.int64'>'
# 	with 646123 stored elements in Compressed Sparse Row format>

# %%
#Text Classification
from sklearn.linear_model import LogisticRegression
start_desc = time.time()

lr = LogisticRegression(solver = 'saga', multi_class = 'multinomial', verbose = 2)
lr.fit(x_train_dtm, y_train)
y_pred_class = lr.predict(x_test_dtm)

end_desc = time.time()
desc_time = print(f"Training time is: {end_desc - start_desc}")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# max_iter reached after 28 seconds
# Training time is: 28.462316274642944
# C:\Users\Lex\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   28.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   28.1s finished

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred_class))
# Out:
# 0.8193031033118775

# %%
y_pred_class
# Out:
# array(['Cabernet Sauvignon', 'Pinot Noir', 'White Blend', ...,
#        'Pinot Noir', 'Bordeaux-style Red Blend', 'Cabernet Sauvignon'],
#       dtype=object)

# %%
#Extra Features
#Price Prediction
x1 = np.array(final_data[['country_num', 'points', 'variety_num']])
y1 = final_data.price

# %%
#Split the second data
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, random_state = 1, test_size = 0.30)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 120, random_state = 1)
rfr.fit(x1_train, y1_train)
y1_pred_class = rfr.predict(x1_test)

# %%
from sklearn.metrics import r2_score
rfr_accuracy = r2_score(y1_test, y1_pred_class)
print(rfr_accuracy)
# Out:
# 0.4745115995423118

# %%
from sklearn.linear_model import ElasticNet
elnet = ElasticNet(fit_intercept = True, normalize = True, max_iter = 100, random_state = 1)
elnet.fit(x1_train, y1_train)
y2_pred_class = elnet.predict(x1_test)

# %%
elnet_accuracy = r2_score(y1_test, y2_pred_class)
print(elnet_accuracy)
# Out:
# -8.080872634552705e-05

# %% [markdown]
# ### Evaluation of the Model and Interpretation of Results

# %%
#Classification Report of the Wine Varieties based on the mined text.
from sklearn.metrics import *
import matplotlib.pyplot as plt
import seaborn as sns
print(classification_report(y_test, y_pred_class))
# Out:
#                           precision    recall  f1-score   support
#
# Bordeaux-style Red Blend       0.76      0.73      0.75      1407
#       Cabernet Sauvignon       0.77      0.82      0.79      3749
#               Chardonnay       0.91      0.94      0.92      4150
#                   Malbec       0.73      0.71      0.72       918
#                   Merlot       0.73      0.66      0.69      1537
#               Pinot Noir       0.85      0.90      0.87      4055
#                Red Blend       0.78      0.76      0.77      2857
#                 Riesling       0.91      0.89      0.90      1555
#               Sangiovese       0.78      0.73      0.75       899
#          Sauvignon Blanc       0.88      0.87      0.87      1778
#                   Shiraz       0.84      0.75      0.79       564
#                    Syrah       0.78      0.74      0.76      1728
#              Tempranillo       0.67      0.66      0.66       731
#              White Blend       0.85      0.79      0.82       766
#                Zinfandel       0.84      0.83      0.83      1115
#
#                 accuracy                           0.82     27809
#                macro avg       0.80      0.78      0.79     27809
#             weighted avg       0.82      0.82      0.82     27809

# %%
#Confusion Matrix of the Wine Variety Classification
conf_mat = confusion_matrix(y_test, y_pred_class)
plt.figure(figsize = (20,20))
sns.heatmap(conf_mat, annot = True, 
            linewidths = 0.2, cmap = 'Reds', cbar = True, 
            fmt = '.0f', square = True,
            xticklabels = top, yticklabels = top)
plt.title("Confusion Matrix", size = 24)
plt.xlabel("Predicted Values", size = 12)
plt.ylabel("Actual Values", size = 12)
plt.show()
#plt.savefig("WineVariety_ConfusionMatrix.png")

#fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
#sns.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)

# %%
#Actual and Predicted Values of the Wine Price based on Variety, Country, and Grade.
results = pd.DataFrame({'Actual Values':y1_test, 'Predicted Values':y1_pred_class})
results.head(10)
# Out:
#         Actual Values  Predicted Values
# 77586            30.0         42.252820
# 27682            38.0         44.475697
# 104531           15.0         19.930469
# 13978            23.0         12.014443
# 1828             44.0         44.475697
# 10532            16.0         23.497975
# 41994            29.0         29.085417
# 71834            23.0         18.919425
# 125921           18.0         27.790198
# 6901             18.0         19.637676

# %% [markdown]
# #### Testing the model using input.

# %%
from numpy import array

try:
    
    wine_desc_input = input("Describe the wine flavor: ")
    string_input = ({wine_desc_input})
    string_conv = CV.transform(string_input)

    wine_variety = array(['Bordeaux-style Red Blend', 'Cabernet Sauvignon', 'Chardonnay', 'Malbec', 'Merlot', 
                          'Pinot Noir', 'Red Blend', 'Riesling', 'Sangiovese', 'Sauvignon Blanc',
                          'Shiraz', 'Syrah', 'Tempranillo', 'White Blend', 'Zinfandel'])

    result = lr.predict_proba(string_conv) #Logistic Regression
    result.max()
    Variety_Result = result.argmax()

    #price_pred = rfr.predict(Variety_Result)
    #wine_price = price_pred[0]

    print("\nWine Variety: " + wine_variety[Variety_Result])
    print(result.max())

except Exception as e:

    print("Please describe the flavor.", e)


    #print("\nWine Price: " + wine_price)
# Out:
# Describe the wine flavor: Nicely oaked blackberry, licorice, vanilla and charred aromas are smooth and sultry. This is an outstanding wine from an excellent year. Forward barrel-spice and mocha flavors adorn core blackberry and raspberry fruit, while this runs long and tastes vaguely chocolaty on the velvety finish. Enjoy this top-notch Tempranillo through 2030.
#
# Wine Variety: Tempranillo
# 0.5767203882779007
